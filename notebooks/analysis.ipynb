# %% [markdown]
# # **EDA**

# %% [markdown]
# ## IMPORTS

# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parent))

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import pandas as pd
import numpy as np
import src.data_processing as dp

# %% [markdown]
# ## Import data

# %%
repos = dp.load_cleaned_data()

commits_df = repos['commits_df']
issues_df = repos['issues_df']

# %% [markdown]
# ## Repo summary

# %%
issues_summary = dp.compute_issues_summary(issues_df)

# %%
commits_summary = dp.compute_commits_summary(commits_df)

# %%
info_summary = dp.compute_info_summary(repos['info_df'])

# %%
print(f'Number Of Unique Contributers : {commits_df['author_name'].nunique()}')
# Out:
# Number Of Unique Contributers : 153

# %%
print('--- Top five Contributors ---')
commits_df['author_name'].value_counts().head(5)
# Out:
# --- Top five Contributors ---
# author_name
# jorenham            26
# Copilot             24
# jbrockmendel        22
# Daniel Lok          16
# Joren Hammudoglu    15
# Name: count, dtype: int64

# %%
# Check the proportion of closed versus open issues:
issues_df['state'].value_counts(normalize=True)
# Out:
# state
# open      0.5
# closed    0.5
# Name: proportion, dtype: float64

# %%
closed_issues = dp.compute_closed_issues_summary(issues_df)

# %%
resolve_time_comparison = dp.compute_resolve_time_comparison(issues_df)

# %%
commits_by_date = dp.compute_commits_by_date(commits_df)
commits_per_day_df =dp.compute_commits_per_day(commits_by_date)
commits_per_day_df = commits_per_day_df.sort_values(by='number_of_commits', ascending=False)

# %%
day_analysis = dp.compute_day_analysis(commits_by_date)

# %%
commit_msg_analysis = dp.compute_commit_msg_analysis(commits_by_date)
commit_msg_analysis  = commit_msg_analysis.sort_values(by= 'avg_message_length', ascending=False)

# %%
summary_df = dp.compute_final_summary(issues_summary, commits_summary, info_summary, closed_issues)

# %%
dp.save_cleaned_data(summary_df, 'summary.csv')
# Out:
# Saved to ../data/cleaned/summary.csv

# %% [markdown]
# ## VISUALIZATIONS

# %%
monthly_graph = issues_df[['repo_name', 'created_at', 'closed_at', 'state']].copy()
monthly_graph['closed_at'] = monthly_graph['closed_at'].dt.to_period('M')
monthly_graph['created_at'] = monthly_graph['created_at'].dt.to_period('M')
# Out:
# /var/folders/_z/rn59b0j50s34wr4hv9tbv6j80000gn/T/ipykernel_38167/1022946263.py:2: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   monthly_graph['closed_at'] = monthly_graph['closed_at'].dt.to_period('M')
# /var/folders/_z/rn59b0j50s34wr4hv9tbv6j80000gn/T/ipykernel_38167/1022946263.py:3: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   monthly_graph['created_at'] = monthly_graph['created_at'].dt.to_period('M')

# %%
#Isolate and count open issues per month:
open_issues = monthly_graph[monthly_graph['state'] == 'open']

open_issues_by_month = open_issues.groupby('created_at').size().reset_index(name='open_issues_count')

# %%
#Isolate and count closed issues per month:
closed_issues = monthly_graph[monthly_graph['state'] == 'closed']

closed_issues = closed_issues.dropna()

closed_issues_by_month = closed_issues.groupby('closed_at').size().reset_index(name='closed_issues_count')

# %% [markdown]
# ### Graphing

# %% [markdown]
# #### Issue Activity over time

# %%
output_dir = Path('../output/visuals')
output_dir.mkdir(parents=True, exist_ok=True)

# %%
#Prepare the graphing area:
sns.set_style('darkgrid')
sns.set_palette("husl")

fig, ax = plt.subplots(figsize=(14, 7))

#plot open issues:
open_issues_by_month['month_str'] = open_issues_by_month['created_at'].astype(str)
sns.lineplot(
    data=open_issues_by_month,
    x='month_str',
    y='open_issues_count',
    label='Issues opened',
    marker='o',
    ax=ax,
    color='navy'
)

#plot closed issues:
closed_issues_by_month['month_str'] = closed_issues_by_month['closed_at'].astype(str)
sns.lineplot(
    ax=ax,
    data=closed_issues_by_month,
    x='month_str',
    y='closed_issues_count',
    label='Issues Closed',
    marker='o',
    color='maroon'
    
)

ax.set_title('Issue Activity Over Time', 
             fontsize=16, fontweight='bold', pad=20)

ax.set_xlabel('Month', fontsize=12, fontweight='bold')
ax.set_ylabel('Number of Open/Closed Issues', fontsize=12, fontweight='bold')

caption = ("Figure 1: Distribution of Open vs Closed issues over time.")
fig.text(0.5, -0.05, caption, ha='center', fontsize=10, style='italic', wrap=True)
plt.tight_layout()

plt.savefig(output_dir/'fig1_issue_activity_overTime.png',
           dpi=85, bbox_inches='tight', facecolor='white')
print(f"✓ Saved: {output_dir / 'fig1_issue_activity_overTime.png'}")
# Out:
# ✓ Saved: ../output/visuals/fig1_issue_activity_overTime.png

# %% [markdown]
# #### Project Health Comparison

# %%
sns.set_style('darkgrid')
sns.set_palette("husl")

fig, ax = plt.subplots(figsize=(12, 6))

sns.barplot(
    data=summary_df,
    y='avg_issue_age_days',
    x='repo_name',
    ax=ax,
    hue='repo_name',
    palette='viridis'
)

# Title and labels
ax.set_title('Average Issue Age by Project Repository', 
             fontsize=16, fontweight='bold', pad=20)
ax.set_xlabel('Repository', fontsize=12, fontweight='bold')
ax.set_ylabel('Average Issue Age (days)', fontsize=12, fontweight='bold')

# Add caption as text below the plot
caption = ("Figure 2: Average age of issues across repositories. "
           "Higher values indicate longer-lived issues, which may suggest "
           "maintenance challenges or complexity.")
fig.text(0.5, -0.05, caption, ha='center', fontsize=10, 
         style='italic', wrap=True)

plt.tight_layout()

plt.savefig(output_dir/'fig2_average_issue_age_by_repo.png',
           dpi=85, bbox_inches='tight', facecolor='white')
print(f"✓ Saved: {output_dir / 'fig2_average_issue_age_by_repo.png'}")
# Out:
# ✓ Saved: ../output/visuals/fig2_average_issue_age_by_repo.png

# %% [markdown]
# #### Contributer Distribution

# %%
#Prepare data to be plotted:
top_contributor_dist = (
    commits_df.groupby(['repo_name', 'author_name'])
        .size()
        .reset_index(name='commit_count')
        .sort_values(['repo_name', 'commit_count'], ascending=[True, False])
)

top_ten_contributors = top_contributor_dist.groupby('repo_name').head(10)

# %%
sns.set_style('darkgrid')
sns.set_palette("husl")
fig, ax = plt.subplots(figsize=(26, 26))

sns.barplot(
    data = top_ten_contributors,
    x = 'author_name',
    y = 'commit_count',
    hue= 'repo_name',
    ax=ax,
    palette='rocket'
    
)

ax.set_xlabel('Author Name', fontsize=12, fontweight='bold')
ax.set_ylabel('Number of Commits', fontsize=12, fontweight='bold')
ax.set_title('Top 10 Contributors per Repo', fontsize=16, fontweight='bold', pad=20)
plt.legend(title='Repository')
plt.xticks(rotation=45, ha='right')

caption =("Figure 3: The Distribution of the Top Ten contributers grouped by repo. The higher the number of contributions, the more active the contributer")
fig.text(0.5, -0.05, caption, ha='center', fontsize=10, style='italic', wrap=True)
plt.tight_layout()

plt.savefig(output_dir/'fig3_top_10_contributers_by_repo.png',
           dpi=85, bbox_inches='tight', facecolor='white')
print(f"✓ Saved: {output_dir / 'fig3_top_10_contributers_by_repo.png'}")
# Out:
# ✓ Saved: ../output/visuals/fig3_top_10_contributers_by_repo.png

# %% [markdown]
# #### Issue Age Distribution

# %%
#Check skewness of data:
sns.set_style('darkgrid')
sns.set_palette('husl')
fig, ax = plt.subplots(figsize=(10,6))
sns.histplot(
    data=issues_df,
    x='issue_age_days',
    kde=True,
    ax=ax,
    color='Blue'
)

ax.set_title('Distributions Of Issue Ages', fontsize=16, fontweight='bold', pad=20)
ax.set_xlabel('Issue Age', fontsize=12, fontweight='bold')
ax.set_ylabel('Count', fontsize=12, fontweight='bold')

caption=("Figure 4: The Distribution of Issue ages.The higher the count more issues have that age")
fig.text(0.5, -0.05, caption, ha='center', fontsize=10, style='italic', wrap=True)

plt.tight_layout()

plt.savefig(output_dir/'fig4_issue_age_distribution.png',
           dpi=85, bbox_inches='tight', facecolor='white')
print(f"✓ Saved: {output_dir / 'fig4_issue_age_distribution.png'}")
# Out:
# ✓ Saved: ../output/visuals/fig4_issue_age_distribution.png

# %%
# Log Transform data using ln(x+1)
sns.set_style('darkgrid')
sns.set_palette("husl")

issues_df['issue_age_days_log'] = np.log1p(issues_df['issue_age_days'])

#Prepare plotting Area:
fig, ax = plt.subplots(figsize=(10,6))

#Plot Data
sns.histplot(
    data=issues_df,
    x='issue_age_days_log',
    kde=True,
    ax=ax,
    color='blue'
)
ax.set_title('Issue Age Distribution', fontsize=16, fontweight='bold', pad=20)
ax.set_xlabel('Log of Issue Age', fontsize=12, fontweight='bold')
ax.set_ylabel('Count', fontsize=12, fontweight='bold')

caption= ("Figure 5: The Natural log(log transformed) of the Age Distribution to normalize the data.")

fig.text(0.5, -0.05, caption, ha='center', fontsize=10, style='italic', wrap=True )

plt.tight_layout()

plt.savefig(output_dir/'fig5_log_issue_age_distribution.png',
           dpi=85, bbox_inches='tight', facecolor='white')
print(f"✓ Saved: {output_dir / 'fig5_log_issue_age_distribution.png'}")
# Out:
# ✓ Saved: ../output/visuals/fig5_log_issue_age_distribution.png

# %% [markdown]
# #### Commits by Day of Week

# %%
#Prepare Data:
day_plot = day_analysis.reset_index()

#Prepare plotting area:
fig, ax = plt.subplots(figsize=(12, 6))

#plot data:
sns.barplot(
    data=day_analysis,
    x='day_of_the_week',
    y='number_of_commits_on_day',
    hue='repo_name',
    ax=ax,
    palette='coolwarm'
)

ax.set_title('Distribution of Commits Across Repos by day of the week', 
             fontsize=16, fontweight='bold', pad=20)
ax.set_xlabel('Day', fontsize=12, fontweight='bold')
ax.set_ylabel('Number of Commits', fontsize=12, fontweight='bold')

caption = ("Figure 6: Total number of commits per repository in the analyzed aranged by day of the week. "
           "Higher commit counts may indicate more active development or "
           "more granular commit practices on such days.")
fig.text(0.5, -0.05, caption, ha='center', fontsize=10, 
         style='italic', wrap=True)

plt.tight_layout()

plt.savefig(output_dir/'fig6_commit_distribution_across_repo.png',
           dpi=85, bbox_inches='tight', facecolor='white')
print(f"✓ Saved: {output_dir / 'fig6_commit_distribution_across_repo.png'}")
# Out:
# ✓ Saved: ../output/visuals/fig6_commit_distribution_across_repo.png
