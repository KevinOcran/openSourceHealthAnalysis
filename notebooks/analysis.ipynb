# %% [markdown]
# # **EDA**

# %% [markdown]
# ## IMPORTS

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import pandas as pd
import numpy as np

# %% [markdown]
# ## Import data

# %%
data_path = Path('../data/cleaned')
data_files = list(data_path.glob('*.csv'))
print(f'{len(data_files)} files found:\n')
for file in data_files:
    print(f'\t-{file.name}')
# Out:
# 3 files found:
#
# 	-cleaned_commits.csv
# 	-cleaned_info.csv
# 	-cleaned_issues.csv

# %%
for file in data_files:
    if 'commits' in file.name:
        commits_df = pd.read_csv(data_path/file.name, parse_dates=['author_date', 'commit_date'])
    elif 'issues' in file.name:
        issues_df = pd.read_csv(data_path/file.name, parse_dates=['created_at', 'closed_at', 'updated_at'])
    elif 'info' in file.name:
        info_df = pd.read_csv(data_path/file.name, parse_dates=['created_at', 'updated_at', 'pushed_at' ])

# %%
# Check repo number:

expected_repos = 5
actual_repos = commits_df['repo_name'].nunique()
assert actual_repos == expected_repos, f"Expected {expected_repos} repositories, but found {actual_repos}"
print(f"✓ Repository count test passed: {actual_repos} repos")
# Out:
# ✓ Repository count test passed: 5 repos

# %%
commits_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   repo_name       500 non-null    object
#  1   sha             500 non-null    object
#  2   author_name     500 non-null    object
#  3   author_email    500 non-null    object
#  4   author_date     500 non-null    datetime64[ns, UTC]
#  5   committer_name  500 non-null    object
#  6   commit_date     500 non-null    datetime64[ns, UTC]
#  7   message         500 non-null    object
#  8   message_length  500 non-null    int64
# dtypes: datetime64[ns, UTC](2), int64(1), object(6)
# memory usage: 35.3+ KB

# %%
issues_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   repo_name            500 non-null    object
#  1   issue_id             500 non-null    int64
#  2   issue_number         500 non-null    int64
#  3   title                500 non-null    object
#  4   state                500 non-null    object
#  5   user_login           500 non-null    object
#  6   created_at           500 non-null    datetime64[ns, UTC]
#  7   updated_at           500 non-null    datetime64[ns, UTC]
#  8   closed_at            250 non-null    datetime64[ns, UTC]
#  9   is_open              500 non-null    bool
#  10  comments             500 non-null    int64
#  11  author_association   500 non-null    object
#  12  labels_count         500 non-null    int64
#  13  issue_age_days       500 non-null    float64
#  14  time_to_close_hours  250 non-null    float64
# dtypes: bool(1), datetime64[ns, UTC](3), float64(2), int64(4), object(5)
# memory usage: 55.3+ KB

# %%
info_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   repo_name    5 non-null      object
#  1   stars        5 non-null      int64
#  2   forks        5 non-null      int64
#  3   open_issues  5 non-null      int64
#  4   language     5 non-null      object
#  5   description  5 non-null      object
#  6   created_at   5 non-null      datetime64[ns, UTC]
#  7   updated_at   5 non-null      datetime64[ns, UTC]
#  8   pushed_at    5 non-null      datetime64[ns, UTC]
# dtypes: datetime64[ns, UTC](3), int64(3), object(3)
# memory usage: 492.0+ bytes

# %% [markdown]
# ## Repo summary

# %%
# Group issue data by repo_name and perform summary stats:

issues_summary = issues_df.groupby('repo_name').agg({
    'issue_id': 'count',
    'issue_age_days': ['mean', 'median']
})

issues_summary = issues_summary.reset_index() 
issues_summary.columns = (
    f'{top_level}_{bottom_level}' for top_level, bottom_level in issues_summary.columns
)
issues_summary
# Out:
#                   repo_name_  issue_id_count  issue_age_days_mean  \
# 0             apache/airflow             100                 7.18
# 1              mlflow/mlflow             100                11.70
# 2                numpy/numpy             100                12.42
# 3          pandas-dev/pandas             100                12.12
# 4  scikit-learn/scikit-learn             100                15.28
#
#    issue_age_days_median
# 0                    7.0
# 1                    6.0
# 2                    5.0
# 3                   10.5
# 4                    6.0

# %%
# Group commit data by repo_name and perform aggregation:

commits_summary = commits_df.groupby('repo_name').agg({
    'sha': 'count'
})
commits_summary = commits_summary.reset_index().rename(columns ={'sha': 'commit_sha_count','repo_name': 'repo_name_'})
commits_summary
# Out:
#                   repo_name_  commit_sha_count
# 0             apache/airflow               100
# 1              mlflow/mlflow               100
# 2                numpy/numpy               100
# 3          pandas-dev/pandas               100
# 4  scikit-learn/scikit-learn               100

# %%
# Group info data by repo_name and perform aggregation:

info_summary = info_df.groupby('repo_name').agg({
    'stars': 'sum'
})

info_summary = info_summary.reset_index().rename(columns={'stars': 'starsgazers_sum'})
info_summary
# Out:
#                    repo_name  starsgazers_sum
# 0             apache/airflow            43145
# 1              mlflow/mlflow            22892
# 2                numpy/numpy            30782
# 3          pandas-dev/pandas            47063
# 4  scikit-learn/scikit-learn            63980

# %%
# join all the summaries into one summary:

summary_df = pd.merge(issues_summary, commits_summary, on='repo_name_', how='inner').rename(columns={'repo_name_': 'repo_name',
'issue_age_days_mean': 'avg_issue_age/days',
 'issue_age_days_median': 'median_issue_age/days'                                                  })
summary_df = pd.merge(summary_df, info_summary, on='repo_name', how='inner' )
summary_df
# Out:
#                    repo_name  issue_id_count  avg_issue_age/days  \
# 0             apache/airflow             100                7.18
# 1              mlflow/mlflow             100               11.70
# 2                numpy/numpy             100               12.42
# 3          pandas-dev/pandas             100               12.12
# 4  scikit-learn/scikit-learn             100               15.28
#
#    median_issue_age/days  commit_sha_count  starsgazers_sum
# 0                    7.0               100            43145
# 1                    6.0               100            22892
# 2                    5.0               100            30782
# 3                   10.5               100            47063
# 4                    6.0               100            63980

# %%
#The number of unique contributors:
commits_df['author_name'].nunique()
# Out:
# 153

# %%
#Top 5 contributors:
print('--- Top five Contributors ---')
commits_df['author_name'].value_counts().head(5)
# Out:
# --- Top five Contributors ---
# author_name
# jorenham            26
# Copilot             24
# jbrockmendel        22
# Daniel Lok          16
# Joren Hammudoglu    15
# Name: count, dtype: int64

# %%
# Check the proportion of closed versus open issues:
issues_df['state'].value_counts(normalize=True)
# Out:
# state
# open      0.5
# closed    0.5
# Name: proportion, dtype: float64

# %%
#Check number of closed vs open issues:
issues_df['state'].value_counts()
# Out:
# state
# open      250
# closed    250
# Name: count, dtype: int64

# %%
#create new column, closed_issues to hold the time it took to close issues (only actually closed issues):
closed_issues = issues_df[['repo_name', 'time_to_close_hours']].dropna(subset=['time_to_close_hours'])

#Group time to close issues by 'repo_name' and calculate 'average_time_to_close issues' for each rep:
closed_issues = closed_issues.groupby('repo_name').agg({
    'time_to_close_hours': 'mean',
}).reset_index().rename(columns={'time_to_close_hours': 'average_time_to_close_hours'})

closed_issues # Its already sorted in ascending order
# Out:
#                    repo_name  average_time_to_close_hours
# 0             apache/airflow                    77.385149
# 1              mlflow/mlflow                    91.657217
# 2                numpy/numpy                    98.301624
# 3          pandas-dev/pandas                   146.507114
# 4  scikit-learn/scikit-learn                   116.270159

# %%
#Create resolve_time_cmpr to hold the time it took to close issues and the author association of closed issues:
resolve_time_cmpr = issues_df[['repo_name', 'time_to_close_hours', 'author_association']].dropna(subset=['time_to_close_hours'])

#Group resolve_time_cmpr by repo_name and author_association and then find the mean and median time for each author_association and repo:
resolve_time_cmpr = resolve_time_cmpr.groupby(['repo_name','author_association']).agg({
    'time_to_close_hours':['mean', 'median']
})

# Flatten new columns:
resolve_time_cmpr.columns = (
    f'{top_level}_{bottom_level}' for top_level, bottom_level in resolve_time_cmpr.columns
)

resolve_time_cmpr = resolve_time_cmpr.rename(columns={
    'time_to_close_hours_mean': 'avg_time_to_close',
    'time_to_close_hours_median': 'median_time_to_close'
})

resolve_time_cmpr
# Out:
#                                               avg_time_to_close  \
# repo_name                 author_association
# apache/airflow            COLLABORATOR               168.833611
#                           CONTRIBUTOR                 63.365262
#                           MEMBER                     117.105000
#                           NONE                        92.533854
# mlflow/mlflow             COLLABORATOR               102.563667
#                           CONTRIBUTOR                 78.401883
#                           MEMBER                       1.800926
#                           NONE                       100.455497
# numpy/numpy               CONTRIBUTOR                141.092037
#                           MEMBER                     111.075988
#                           NONE                        62.102768
# pandas-dev/pandas         CONTRIBUTOR                130.148948
#                           MEMBER                     180.093981
#                           NONE                       143.321570
# scikit-learn/scikit-learn CONTRIBUTOR                148.077564
#                           MEMBER                     155.067925
#                           NONE                        41.942431
#
#                                               median_time_to_close
# repo_name                 author_association
# apache/airflow            COLLABORATOR                  168.833611
#                           CONTRIBUTOR                    37.834861
#                           MEMBER                        117.105000
#                           NONE                           92.560833
# mlflow/mlflow             COLLABORATOR                   44.933056
#                           CONTRIBUTOR                    39.375000
#                           MEMBER                          2.062778
#                           NONE                           51.676528
# numpy/numpy               CONTRIBUTOR                    45.389444
#                           MEMBER                         25.186667
#                           NONE                           36.644167
# pandas-dev/pandas         CONTRIBUTOR                    98.977500
#                           MEMBER                        162.783333
#                           NONE                           32.611111
# scikit-learn/scikit-learn CONTRIBUTOR                    84.578333
#                           MEMBER                         72.014444
#                           NONE                           19.630000

# %%
#create commits_by_date to store repo_name, author_date and message_length:
commits_by_date = commits_df[['repo_name', 'author_date','message_length' ]].copy()

commits_by_date['day_of_the_week'] = commits_by_date['author_date'].dt.day_name()

commits_by_date['author_date'] = commits_by_date['author_date'].dt.date

#Create commits_per_day_df to hold the count of the number of commits per day by repo_name:
commits_per_day = commits_by_date.groupby(['repo_name', 'author_date']).size()

commits_per_day_df = commits_per_day.reset_index(name='number_of_commits')

commits_per_day_df = commits_per_day_df.set_index(['repo_name', 'author_date'])

commits_per_day_df.sort_values(by='number_of_commits', ascending=False)
# Out:
#                                        number_of_commits
# repo_name                 author_date
# apache/airflow            2025-11-07                  66
# mlflow/mlflow             2025-11-07                  23
#                           2025-11-03                  19
#                           2025-11-05                  18
# pandas-dev/pandas         2025-11-04                  17
# ...                                                  ...
#                           2025-11-02                   1
# scikit-learn/scikit-learn 2025-10-22                   1
#                           2025-10-15                   1
#                           2025-11-01                   1
#                           2025-11-10                   1
#
# [67 rows x 1 columns]

# %%
#Which days had the most commits:
day_analysis = commits_by_date.groupby(['repo_name', 'day_of_the_week']).agg({
    'day_of_the_week': 'count'
})

day_analysis = day_analysis.rename(columns={
    'day_of_the_week': 'number_of_commits_on_day'
})

day_analysis
# Out:
#                                            number_of_commits_on_day
# repo_name                 day_of_the_week
# apache/airflow            Friday                                 66
#                           Saturday                               13
#                           Sunday                                 12
#                           Thursday                                9
# mlflow/mlflow             Friday                                 23
#                           Monday                                 23
#                           Saturday                                6
#                           Sunday                                  1
#                           Thursday                               15
#                           Tuesday                                14
#                           Wednesday                              18
# numpy/numpy               Friday                                 24
#                           Monday                                  6
#                           Saturday                               10
#                           Sunday                                  6
#                           Thursday                               21
#                           Tuesday                                19
#                           Wednesday                              14
# pandas-dev/pandas         Friday                                 13
#                           Monday                                 19
#                           Saturday                               10
#                           Sunday                                  1
#                           Thursday                               15
#                           Tuesday                                22
#                           Wednesday                              20
# scikit-learn/scikit-learn Friday                                 20
#                           Monday                                 22
#                           Saturday                                6
#                           Sunday                                  2
#                           Thursday                               22
#                           Tuesday                                13
#                           Wednesday                              15

# %%
#Message Length analysis:
commit_msg_analysis = commits_by_date.copy()
commit_msg_analysis = commit_msg_analysis.groupby(['repo_name']).agg({
    'message_length': ['mean', 'median']
})

# Flatten new columns:
commit_msg_analysis.columns = (
    f'{top_level}_{bottom_level}' for top_level, bottom_level in commit_msg_analysis.columns
)

commit_msg_analysis = commit_msg_analysis.rename(columns={
    'message_length_mean': 'avg_message_length',
    'message_length_median': 'median_message_length'
})

    
commit_msg_analysis.sort_values(by= 'avg_message_length', ascending=False)
# Out:
#                            avg_message_length  median_message_length
# repo_name
# mlflow/mlflow                          180.07                  164.5
# numpy/numpy                            178.18                   80.5
# apache/airflow                         145.82                   75.5
# scikit-learn/scikit-learn               95.82                   73.0
# pandas-dev/pandas                       81.60                   64.5

# %% [markdown]
# ## VISUALIZATIONS

# %%
#Prepare the data in issues_df['closed_at', 'created_at'] to be graphed:
#Store repo_name, created_at, closed_at, and state in monthly_graoh:
monthly_graph = issues_df[['repo_name', 'created_at', 'closed_at', 'state']].copy()

#Convert closed_at and created_at to year-month format:
monthly_graph['closed_at'] = monthly_graph['closed_at'].dt.to_period('M')

monthly_graph['created_at'] = monthly_graph['created_at'].dt.to_period('M')

monthly_graph
# Out:
# /var/folders/_z/rn59b0j50s34wr4hv9tbv6j80000gn/T/ipykernel_5097/339854433.py:6: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   monthly_graph['closed_at'] = monthly_graph['closed_at'].dt.to_period('M')
# /var/folders/_z/rn59b0j50s34wr4hv9tbv6j80000gn/T/ipykernel_5097/339854433.py:8: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   monthly_graph['created_at'] = monthly_graph['created_at'].dt.to_period('M')
#                      repo_name created_at closed_at   state
# 0    scikit-learn/scikit-learn    2025-11       NaT    open
# 1    scikit-learn/scikit-learn    2025-11   2025-11  closed
# 2    scikit-learn/scikit-learn    2025-11       NaT    open
# 3    scikit-learn/scikit-learn    2025-11   2025-11  closed
# 4    scikit-learn/scikit-learn    2025-11       NaT    open
# ..                         ...        ...       ...     ...
# 495             apache/airflow    2025-10       NaT    open
# 496             apache/airflow    2025-10       NaT    open
# 497             apache/airflow    2025-10   2025-11  closed
# 498             apache/airflow    2025-10       NaT    open
# 499             apache/airflow    2025-10   2025-10  closed
#
# [500 rows x 4 columns]

# %%
monthly_graph.loc(0)

# %%
#Isolate and count open issues per month:
open_issues = monthly_graph[monthly_graph['state'] == 'open']

open_issues_by_month = open_issues.groupby('created_at').size().reset_index(name='open_issues_count')

open_issues_by_month
# Out:
#   created_at  open_issues_count
# 0    2025-09                 20
# 1    2025-10                135
# 2    2025-11                 95

# %%
#Isolate and count closed issues per month:
closed_issues = monthly_graph[monthly_graph['state'] == 'closed']

closed_issues = closed_issues.dropna()

closed_issues_by_month = closed_issues.groupby('closed_at').size().reset_index(name='closed_issues_count')

closed_issues_by_month
# Out:
#   closed_at  closed_issues_count
# 0   2025-09                   20
# 1   2025-10                  152
# 2   2025-11                   78

# %% [markdown]
# ### Graphing

# %% [markdown]
# #### Issue Activity over time

# %%
#Prepare the graphing area:
sns.set_style('dark')
plt.figure(figsize=(10,8.4))
axis = plt.gca()

#plot open issues:
open_issues_by_month['month_str'] = open_issues_by_month['created_at'].astype(str)
sns.lineplot(
    ax=axis,
    data=open_issues_by_month,
    x='month_str',
    y='open_issues_count',
    label='Issues opened',
    marker='o'
)

#plot closed issues:
closed_issues_by_month['month_str'] = closed_issues_by_month['closed_at'].astype(str)
sns.lineplot(
    ax=axis,
    data=closed_issues_by_month,
    x='month_str',
    y='closed_issues_count',
    label='Issues Closed',
    marker='o'
    
)
plt.title('Issue Activity Over Time')
plt.xlabel('Month')
plt.ylabel('Number of Open/Closed Issues')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #### Project Health Comparison

# %%
#Prepare Graphing area:
sns.set_style('darkgrid')
plt.figure(figsize=(10,6))
ax = plt.gca()

#Plot chart:
sns.barplot(
    data=summary_df,
    y='avg_issue_age/days',
    x='repo_name',
    ax=ax
)
plt.title('Average Issue Age by Project Repository')
plt.xlabel('Project')
plt.ylabel('Average Issue Age(days)')
# Out:
# Text(0, 0.5, 'Average Issue Age(days)')

# %% [markdown]
# #### Contributer Distribution

# %%
#Prepare data to be plotted:
top_contributor_dist = (
    commits_df.groupby(['repo_name', 'author_name'])
        .size()
        .reset_index(name='commit_count')
        .sort_values(['repo_name', 'commit_count'], ascending=[True, False])
)

top_ten_contributors = top_contributor_dist.groupby('repo_name').head(10)

top_ten_contributors
# Out:
#                      repo_name            author_name  commit_count
# 12              apache/airflow         GUAN-HAO HUANG            15
# 9               apache/airflow           ChenChen Lai            10
# 8               apache/airflow          Chao-Hung Wan             9
# 16              apache/airflow           Jarek Potiuk             9
# 17              apache/airflow         Jens Scheffler             9
# 4               apache/airflow            Anusha Kovi             8
# 2               apache/airflow            Amogh Desai             7
# 21              apache/airflow        Pierre Jeambrun             5
# 26              apache/airflow                Vincent             3
# 7               apache/airflow           Bugra Ozturk             2
# 34               mlflow/mlflow                Copilot            24
# 36               mlflow/mlflow             Daniel Lok            16
# 44               mlflow/mlflow          Yuki Watanabe            14
# 42               mlflow/mlflow            Serena Ruan            12
# 37               mlflow/mlflow      Harutaka Kawamura             8
# 47               mlflow/mlflow        mlflow-app[bot]             7
# 32               mlflow/mlflow             Ben Wilson             3
# 41               mlflow/mlflow        Samraj Moorjani             3
# 31               mlflow/mlflow        Alkis Polyzotis             2
# 33               mlflow/mlflow              Bryan Qiu             2
# 71                 numpy/numpy               jorenham            26
# 54                 numpy/numpy       Joren Hammudoglu            15
# 57                 numpy/numpy            Matti Picus            12
# 51                 numpy/numpy         Charles Harris             9
# 67                 numpy/numpy       Warren Weckesser             6
# 69                 numpy/numpy        dependabot[bot]             4
# 48                 numpy/numpy        Abhishek Tiwari             3
# 49                 numpy/numpy      Amelia Thurdekoos             2
# 50                 numpy/numpy    Britney Whittington             2
# 52                 numpy/numpy      Christine P. Chai             2
# 111          pandas-dev/pandas           jbrockmendel            22
# 94           pandas-dev/pandas       Matthew Roeschke            13
# 92           pandas-dev/pandas                Lu Yibo             6
# 85           pandas-dev/pandas  Joris Van den Bossche             4
# 106          pandas-dev/pandas          Wang Haoxiang             4
# 99           pandas-dev/pandas        Patrick Hoefler             3
# 100          pandas-dev/pandas       Richard Shadrach             3
# 75           pandas-dev/pandas                 Aniket             2
# 77           pandas-dev/pandas      Christine P. Chai             2
# 93           pandas-dev/pandas   Marco Edward Gorelli             2
# 125  scikit-learn/scikit-learn      Christine P. Chai            11
# 135  scikit-learn/scikit-learn            Loïc Estève            10
# 156  scikit-learn/scikit-learn       scikit-learn-bot            10
# 127  scikit-learn/scikit-learn         Dea María Léon             8
# 142  scikit-learn/scikit-learn         Olivier Grisel             6
# 143  scikit-learn/scikit-learn            Omar Salman             5
# 130  scikit-learn/scikit-learn        François Paugam             4
# 136  scikit-learn/scikit-learn               Lucy Liu             4
# 121  scikit-learn/scikit-learn             Anne Beyer             3
# 123  scikit-learn/scikit-learn          Arthur Lacote             3

# %%
plt.figure(figsize=(30,26))
sns.set_style('darkgrid')

sns.barplot(
    data = top_ten_contributors,
    x = 'author_name',
    y = 'commit_count',
    hue= 'repo_name'
)

plt.xlabel('Author Name')
plt.ylabel('Number of Commits')
plt.title('Top 10 Contributors per Repo')
plt.legend(title='Repository')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# %% [markdown]
# #### Issue Age Distribution

# %%
#Check skewness of data:
sns.set_style('dark')
plt.figure(figsize=(10,6))
sns.histplot(
    data=issues_df,
    x='issue_age_days',
    kde=True,
)
# Out:
# <Axes: xlabel='issue_age_days', ylabel='Count'>

# %%
# Log Transform data using ln(x+1)
issues_df['issue_age_days_log'] = np.log1p(issues_df['issue_age_days'])

#Prepare plotting Area:
sns.set_style('dark')
plt.figure(figsize=(10,6))

#Plot Data
sns.histplot(
    data=issues_df,
    x='issue_age_days_log',
    kde=True,
)
plt.title('Issue Age Distribution')
plt.xlabel('Log of Issue Age')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# #### Commits by Day of Week

# %%
#Prepare Data:
day_plot = day_analysis.reset_index()

#Prepare plotting area:
sns.set_style('whitegrid')
plt.figure(figsize=(12,7))

#plot data:
sns.barplot(
    data=day_analysis,
    x='day_of_the_week',
    y='number_of_commits_on_day',
    hue='repo_name'
)

plt.title('Distribution of Commits Across Repos by day of the week')
plt.xlabel('Day')
plt.ylabel('Number of Commits')
# Out:
# Text(0, 0.5, 'Number of Commits')

# %% [markdown]
# # TESTING

# %%
#Data Integrity test:

issue_age_test = issues_df[
    issues_df['closed_at'].notna()]

issue_age_test
# Out:
#                      repo_name    issue_id  issue_number  \
# 1    scikit-learn/scikit-learn  3604361646         32678
# 3    scikit-learn/scikit-learn  3601823994         32671
# 6    scikit-learn/scikit-learn  3593607508         32658
# 7    scikit-learn/scikit-learn  3592369520         32655
# 8    scikit-learn/scikit-learn  3589555370         32650
# ..                         ...         ...           ...
# 487             apache/airflow  3570901550         57555
# 491             apache/airflow  3569953911         57542
# 493             apache/airflow  3569275797         57534
# 497             apache/airflow  3566934352         57507
# 499             apache/airflow  3566652657         57495
#
#                                                  title   state  \
# 1    ⚠️ CI failed on Linux_Runs.pylatest_conda_forg...  closed
# 3                load_iris example does not match text  closed
# 6    ⚠️ CI failed on Linux_Nightly.pylatest_pip_sci...  closed
# 7    Reduce “Can I take this?” by front-loading /ta...  closed
# 8                      Finish Python 3.10 -> 3.11 bump  closed
# ..                                                 ...     ...
# 487                 No relabeling of connection fields  closed
# 491                            Internal Error on login  closed
# 493                  Airflow 3.1.1 oauth login failure  closed
# 497  Error when email_on_failure is enabled due to ...  closed
# 499  LocalExecutor seems to support parallelism=0, ...  closed
#
#            user_login                created_at                updated_at  \
# 1    scikit-learn-bot 2025-11-09 02:35:37+00:00 2025-11-09 12:14:17+00:00
# 3            steveire 2025-11-07 20:02:31+00:00 2025-11-09 08:01:23+00:00
# 6    scikit-learn-bot 2025-11-06 02:34:11+00:00 2025-11-10 05:40:41+00:00
# 7     freesoulinempty 2025-11-05 18:49:47+00:00 2025-11-06 08:04:23+00:00
# 8             lesteve 2025-11-05 06:37:40+00:00 2025-11-05 09:42:46+00:00
# ..                ...                       ...                       ...
# 487            Dev-iL 2025-10-30 13:50:24+00:00 2025-11-05 05:33:07+00:00
# 491           mattsax 2025-10-30 10:09:42+00:00 2025-11-03 18:02:42+00:00
# 493        anavrotski 2025-10-30 07:31:21+00:00 2025-11-08 00:53:55+00:00
# 497      karenbraganz 2025-10-29 16:42:44+00:00 2025-11-05 17:32:45+00:00
# 499     alkismavridis 2025-10-29 15:39:28+00:00 2025-10-31 18:13:04+00:00
#
#                     closed_at  is_open  comments author_association  \
# 1   2025-11-09 12:14:10+00:00    False         1        CONTRIBUTOR
# 3   2025-11-09 08:01:23+00:00    False         3               NONE
# 6   2025-11-10 05:40:41+00:00    False         3        CONTRIBUTOR
# 7   2025-11-06 08:04:23+00:00    False         2               NONE
# 8   2025-11-05 09:00:35+00:00    False         0             MEMBER
# ..                        ...      ...       ...                ...
# 487 2025-11-05 05:33:07+00:00    False         3        CONTRIBUTOR
# 491 2025-11-03 18:02:42+00:00    False         8               NONE
# 493 2025-11-08 00:53:55+00:00    False         4               NONE
# 497 2025-11-05 17:32:45+00:00    False         4       COLLABORATOR
# 499 2025-10-31 18:13:04+00:00    False         2        CONTRIBUTOR
#
#      labels_count  issue_age_days  time_to_close_hours
# 1               1             0.0             9.642500
# 3               1             1.0            35.981111
# 6               0             4.0            99.108333
# 7               1             0.0            13.243333
# 8               0             0.0             2.381944
# ..            ...             ...                  ...
# 487             6             5.0           135.711944
# 491             3             4.0           103.883333
# 493             5             8.0           209.376111
# 497             7             7.0           168.833611
# 499             3             2.0            50.560000
#
# [250 rows x 15 columns]

# %%
issue_sample = issue_age_test.sample(5)

# %%
issue_sample['age_test'] = np.nan

issue_sample['age_test'] = (issue_sample['closed_at'] - issue_sample['created_at']).dt.days

issue_sample['age_test']
# Out:
# 150         2.0
# 57          1.0
# 259         0.0
# 292         1.0
# 464         3.0
# age_test    NaN
# Name: age_test, dtype: float64
